# %%
import pandas as pd
import geopandas as gpd
import altair as alt
from altair.expr import datum
import json
alt.renderers.enable('notebook')
alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
def generate_cc_lookup():
    cc = dict()
    cc['AO'] = 'Angola'; cc['BF'] = 'Burkina Faso'; cc['BJ'] = 'Benin'; cc['BU'] = 'Burundi'
    cc['CD'] = 'Dem. Rep. Congo'; cc['CF'] = 'Central African Rep.'; cc['CI'] = 'Côte d\'Ivoire'
    cc['CM'] = 'Cameroon'; cc['GA'] = 'Gabon'; cc['GH'] = 'Ghana'; cc['GN'] = 'Guinea'; cc['KE'] = 'Kenya'
    cc['KM'] = None; cc['LB'] = 'Liberia'; cc['LS'] = 'Lesotho'; cc['MD'] = 'Madagascar'; cc['ML'] = 'Mali'
    cc['MW'] = 'Malawi'; cc['MZ'] = 'Mozambique'; cc['NG'] = 'Nigeria'; cc['NI'] = 'Niger'; cc['NM'] = 'Namibia'
    cc['RW'] = 'Rwanda'; cc['SL'] = 'Sierra Leone'; cc['SN'] = 'Senegal';  cc['TD'] = 'Chad'; cc['TG'] = 'Togo'
    cc['TZ'] = 'Tanzania'; cc['UG'] = 'Uganda'; cc['ZM'] = 'Zambia' ; cc['ZW'] = 'Zimbabwe'
    
    return cc

# %%
dhs_info = 'dhs_info_for_climate_extraction_26sept2018.csv'
df = pd.read_csv(dhs_info, sep=',')
country_codes = df.dhscc.unique()

data = df.loc[:, ['longnum', 'latnum', 'dhscc']]

c_info = list()
#print(country_codes)

cc_dict = generate_cc_lookup()

for cc in country_codes:
    curr_info = df[data.dhscc == cc]
    c_info.append(curr_info)

# %%
path = gpd.datasets.get_path('naturalearth_lowres')
world = gpd.read_file(path)
africa = world[world['continent'] == 'Africa']

angola = africa[africa['name'] == cc_dict['AO']]

#print(angola)

angola_json = json.loads(angola.to_json())
angola_data = alt.Data(values=angola_json)

geo_chart = alt.Chart(angola_data).mark_geoshape(
    stroke='black',
    strokeWidth=1
).properties(
    width=160,
    height=160
)

#geo_chart

curr_cc = 'AO'
base = alt.Chart(c_info[0]).mark_point(
    size=1
).encode(
    alt.X('longnum',
        scale=alt.Scale(zero=False)
    ),
    alt.Y('latnum',
        scale=alt.Scale(zero=False)
    ),
    color='dhscc:N'
)
#base + geo_chart
#geo_chart + base
#print(angola)
#geo_chart

# %%
def plot_c(cc_info, country_geo):
    country_json = json.loads(country_geo.to_json())
    country_data = alt.Data(values=country_json)
    
    geo_chart = alt.Chart(country_data).mark_geoshape(
        stroke='black',
        strokeWidth=1
    ).properties(
        width=160,
        height=160
    )
    
    curr_cc = cc_info.dhscc
    curr_plot = alt.Chart(cc_info).mark_point(
        size=1
    ).encode(
        alt.X('longnum',
            scale=alt.Scale(zero=False)
        ),
        alt.Y('latnum',
            scale=alt.Scale(zero=False)
        ),
        color='dhscc:N'
    )

    return geo_chart + curr_plot

# %%
#plot_c(c_info[0], africa[africa['name'] == cc_dict['AO']])
chart1 = alt.hconcat(plot_c(c_info[0], africa[africa['name'] == cc_dict['AO']]), plot_c(c_info[1], africa[africa['name'] == cc_dict['BF']]))
chart5 = alt.hconcat(chart1, plot_c(c_info[2], africa[africa['name'] == cc_dict['BJ']]))
chart2 = alt.hconcat(plot_c(c_info[3], africa[africa['name'] == cc_dict['BU']]), plot_c(c_info[4], africa[africa['name'] == cc_dict['CD']]))
chart6 = alt.hconcat(chart2, plot_c(c_info[5], africa[africa['name'] == cc_dict['CF']]))
chart3 = alt.hconcat(plot_c(c_info[6], africa[africa['name'] == cc_dict['CI']]), plot_c(c_info[7], africa[africa['name'] == cc_dict['CM']]))
chart7 = alt.hconcat(chart3, plot_c(c_info[8], africa[africa['name'] == cc_dict['GA']]))
chart4 = alt.hconcat(plot_c(c_info[9], africa[africa['name'] == cc_dict['GH']]))
big_plot = alt.vconcat(alt.vconcat(chart5, chart6), alt.vconcat(chart7, chart4))
big_plot

# %%
#chart1 = alt.hconcat(plot_c(c_info[10]), plot_c(c_info[11]), plot_c(c_info[12]))
#chart2 = alt.hconcat(plot_c(c_info[13]), plot_c(c_info[14]), plot_c(c_info[15]))
#chart3 = alt.hconcat(plot_c(c_info[16]), plot_c(c_info[17]), plot_c(c_info[18]))
#chart4 = alt.hconcat(plot_c(c_info[19]))
#big_plot2 = alt.vconcat(alt.vconcat(chart1, chart2), alt.vconcat(chart3, chart4))
#big_plot2

# %%
#chart1 = alt.hconcat(plot_c(c_info[20]), plot_c(c_info[21]), plot_c(c_info[22]))
#chart2 = alt.hconcat(plot_c(c_info[23]), plot_c(c_info[24]), plot_c(c_info[25]))
#chart3 = alt.hconcat(plot_c(c_info[26]), plot_c(c_info[27]), plot_c(c_info[28]))
#chart4 = alt.hconcat(plot_c(c_info[29]), plot_c(c_info[30]))
#big_plot3 = alt.vconcat(alt.vconcat(chart1, chart2), alt.vconcat(chart3, chart4))
#big_plot3

# %%
def generate_cc_lookup_2():
    cc = dict()
    cc['AO'] = 'Angola'; cc['BF'] = 'Burkina Faso'; cc['BJ'] = 'Benin'; cc['BU'] = 'Burundi'
    cc['CD'] = 'Democratic Republic of Congo'; cc['CF'] = 'Central African Republic'; cc['CI'] = 'Cote d`Ivoire'
    cc['CM'] = 'Cameroon'; cc['GA'] = 'Gabon'; cc['GH'] = 'Ghana'; cc['GN'] = 'Guinea'; cc['KE'] = 'Kenya'
    cc['KM'] = 'Comoros'; cc['LB'] = 'Liberia'; cc['LS'] = 'Lesotho'; cc['MD'] = 'Madagascar'; cc['ML'] = 'Mali'
    cc['MW'] = 'Malawi'; cc['MZ'] = 'Mozambique'; cc['NG'] = 'Nigeria'; cc['NI'] = 'Niger'; cc['NM'] = 'Namibia'
    cc['RW'] = 'Rwanda'; cc['SL'] = 'Sierra Leone'; cc['SN'] = 'Senegal';  cc['TD'] = 'Chad'; cc['TG'] = 'Togo'
    cc['TZ'] = 'Tanzania'; cc['UG'] = 'Uganda'; cc['ZM'] = 'Zambia' ; cc['ZW'] = 'Zimbabwe'
    
    return cc

# %%
path = '../Africa_SHP/Africa.shp'
africa = gpd.read_file(path)

cc_dict = generate_cc_lookup_2()

angola = africa[africa['COUNTRY'] == 'Angola']
#print(angola)

angola_json = json.loads(angola.to_json())
angola_data = alt.Data(values=angola_json)

geo_chart = alt.Chart(angola_data).mark_geoshape(
    stroke='black',
    strokeWidth=1
).properties(
    width=160,
    height=160
)

#geo_chart

base = alt.Chart(c_info[0]).mark_point(
    size=1
).encode(
    alt.X('longnum',
        scale=alt.Scale(zero=False)
    ),
    alt.Y('latnum',
        scale=alt.Scale(zero=False)
    ),
    color='dhscc:N'
)

#geo_chart + base
#print(angola)

# %%
#plot_c(c_info[0], africa[africa['name'] == cc_dict['AO']])
chart1 = alt.hconcat(plot_c(c_info[0], africa[africa['COUNTRY'] == cc_dict['AO']]), plot_c(c_info[1], africa[africa['COUNTRY'] == cc_dict['BF']]))
chart5 = alt.hconcat(chart1, plot_c(c_info[2], africa[africa['COUNTRY'] == cc_dict['BJ']]))
chart2 = alt.hconcat(plot_c(c_info[3], africa[africa['COUNTRY'] == cc_dict['BU']]), plot_c(c_info[4], africa[africa['COUNTRY'] == cc_dict['CD']]))
chart6 = alt.hconcat(chart2, plot_c(c_info[5], africa[africa['COUNTRY'] == cc_dict['CF']]))
chart3 = alt.hconcat(plot_c(c_info[6], africa[africa['COUNTRY'] == cc_dict['CI']]), plot_c(c_info[7], africa[africa['COUNTRY'] == cc_dict['CM']]))
chart7 = alt.hconcat(chart3, plot_c(c_info[8], africa[africa['COUNTRY'] == cc_dict['GA']]))
chart4 = alt.hconcat(plot_c(c_info[9], africa[africa['COUNTRY'] == cc_dict['GH']]))
big_plot = alt.vconcat(alt.vconcat(chart5, chart6), alt.vconcat(chart7, chart4))
big_plot
